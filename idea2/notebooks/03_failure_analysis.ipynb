# %% [markdown]
# # Failure Analysis
#
# Set `checkpoint` to a trained binary checkpoint, then run the cell.

# %%
checkpoint = 'results/csv/<run>/best.pt'
import subprocess, sys
subprocess.run([
    sys.executable, 'analyze_binary.py',
    '--checkpoint', checkpoint,
    '--batch_size', '16',
    '--num_batches', '2',
    '--max_cases', '8',
], check=True)
